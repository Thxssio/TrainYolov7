# %% [markdown]
# <a href="https://colab.research.google.com/github/Thxssio/TrainYolov7/blob/main/YOLOv7Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Train YOLOv7 on a Custom Dataset***
#
#
#
#
#
#
# ### Preparing a Custom Dataset
# Criando dataset
#
#     baixar imagens OK
#     baixar e instalar labelimg Ok
#     anotar imagens OK
#     dividir as imagens em train e test OK
# Configurar o arquivo data OK
#
# Configurar o arquivo cfg OK
#     treinar modelo
#
#     baixar arquivo de peso
# testar em scripts
#
#
#     python train.py --workers 1 --device 0 --batch-size 8 --epochs 100 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --name yolov7_custom --weights yolov7.pt

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# Download YOLOv7 repository and install requirements
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -r requirements.txt

# %% [markdown]
# # Begin Custom Training
#
# We're ready to start custom training.

# %%
# download COCO starting checkpoint
# %cd /content/yolov7
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7_training.pt

# %%
# run this cell to begin training
# %cd /content/yolov7
# !python train.py --workers 1 --device 0 --batch-size 8 --epochs 100 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --name yolov7_custom --weights 'yolov7_training.pt'
# Out:
# /content/yolov7
# 2023-04-27 01:35:41.119923: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 01:35:42.026717: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-122-g3b41c2c torch 2.0.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...
